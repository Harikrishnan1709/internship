# %%
import numpy as np
import pandas as pd

# %%
s={
    'Student':['Hari','Sai','bharath','vinoth'],
    'Marks':[95,98,94,np.nan]
}

# %%
df=pd.DataFrame(s)
print(df)
# Out:
#    Student  Marks
# 0     Hari   95.0
# 1      Sai   98.0
# 2  bharath   94.0
# 3   vinoth    NaN

# %%
df.dropna()
# Out:
#    Student  Marks
# 0     Hari   95.0
# 1      Sai   98.0
# 2  bharath   94.0

# %%
df.dropna(axis=1)
# Out:
#    Student
# 0     Hari
# 1      Sai
# 2  bharath
# 3   vinoth

# %%
df.fillna(value = 'Filling value')
# Out:
#    Student          Marks
# 0     Hari           95.0
# 1      Sai           98.0
# 2  bharath           94.0
# 3   vinoth  Filling value

# %%
df.fillna(value = '45')
# Out:
#    Student Marks
# 0     Hari  95.0
# 1      Sai  98.0
# 2  bharath  94.0
# 3   vinoth    45

# %%
s = df['Marks'].fillna(value = df['Marks'].mean())
s
# Out:
# 0    95.000000
# 1    98.000000
# 2    94.000000
# 3    95.666667
# Name: Marks, dtype: float64

# %%
df['Marks'].fillna(value = df['Marks'].mean(), inplace = True)
# Out:
# <ipython-input-12-8cfb06369c33>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Marks'].fillna(value = df['Marks'].mean(), inplace = True)

# %%
df
# Out:
#    Student      Marks
# 0     Hari  95.000000
# 1      Sai  98.000000
# 2  bharath  94.000000
# 3   vinoth  95.666667

# %%
Company={
    'Emp_id':[100,101,102,103,104,105],
    'Emp_name':['Hari','sai','bharath','sanjay','saravanan','karthik'],
    'Emp_salary':[40000,35000,55000,32000,32000,np.nan]
}

# %%
df=pd.DataFrame(Company)
print(df)
# Out:
#    Emp_id   Emp_name  Emp_salary
# 0     100       Hari     40000.0
# 1     101        sai     35000.0
# 2     102    bharath     55000.0
# 3     103     sanjay     32000.0
# 4     104  saravanan     32000.0
# 5     105    karthik         NaN

# %%
df.groupby('Emp_salary').sum()
# Out:
#             Emp_id         Emp_name
# Emp_salary
# 32000.0        207  sanjaysaravanan
# 35000.0        101              sai
# 40000.0        100             Hari
# 55000.0        102          bharath

# %%
df.groupby('Emp_name').count()
# Out:
#            Emp_id  Emp_salary
# Emp_name
# Hari            1           1
# bharath         1           1
# karthik         1           0
# sai             1           1
# sanjay          1           1
# saravanan       1           1

# %%
# byComp['Emp_salary'].mean()
mean_salary_by_name = df.groupby('Emp_name')['Emp_salary'].mean()
print(mean_salary_by_name)
# Out:
# Emp_name
# Hari         40000.0
# bharath      55000.0
# karthik          NaN
# sai          35000.0
# sanjay       32000.0
# saravanan    32000.0
# Name: Emp_salary, dtype: float64

# %%
df.groupby('Emp_name').describe()
# Out:
#           Emp_id                                               Emp_salary  \
#            count   mean std    min    25%    50%    75%    max      count
# Emp_name
# Hari         1.0  100.0 NaN  100.0  100.0  100.0  100.0  100.0        1.0
# bharath      1.0  102.0 NaN  102.0  102.0  102.0  102.0  102.0        1.0
# karthik      1.0  105.0 NaN  105.0  105.0  105.0  105.0  105.0        0.0
# sai          1.0  101.0 NaN  101.0  101.0  101.0  101.0  101.0        1.0
# sanjay       1.0  103.0 NaN  103.0  103.0  103.0  103.0  103.0        1.0
# saravanan    1.0  104.0 NaN  104.0  104.0  104.0  104.0  104.0        1.0
#
#
#               mean std      min      25%      50%      75%      max
# Emp_name
# Hari       40000.0 NaN  40000.0  40000.0  40000.0  40000.0  40000.0
# bharath    55000.0 NaN  55000.0  55000.0  55000.0  55000.0  55000.0
# karthik        NaN NaN      NaN      NaN      NaN      NaN      NaN
# sai        35000.0 NaN  35000.0  35000.0  35000.0  35000.0  35000.0
# ...

# %%
std_salary_by_name = df.groupby('Emp_name')['Emp_salary'].std()
print(std_salary_by_name)
# Out:
# Emp_name
# Hari        NaN
# bharath     NaN
# karthik     NaN
# sai         NaN
# sanjay      NaN
# saravanan   NaN
# Name: Emp_salary, dtype: float64

# %%
import numpy as np
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-42c47a7a-4b25-4db1-a30b-21102d953caf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-42c47a7a-4b25-4db1-a30b-21102d953caf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('Student_performance_data _.csv')

# %%
df.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
df.tail()
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
#       Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 2387         2         0                4                1       0      0
# 2388         4         1                4                0       1      0
# 2389        20         0                2                0       0      0
# 2390        17         0                2                0       1      1
# 2391        13         0                2                0       0      0
#
#       Volunteering       GPA  GradeClass
# ...
